# %% [markdown]
# # Requirments

# %%
# !pip install diffusers --upgrade
# !pip install invisible_watermark transformers accelerate safetensors

# %%
from diffusers import DiffusionPipeline
import torch

pipe = DiffusionPipeline.from_pretrained("stabilityai/stable-diffusion-xl-base-1.0", torch_dtype=torch.float16, use_safetensors=True, variant="fp16")
pipe.to("cuda")

# if using torch < 2.0
# pipe.enable_xformers_memory_efficient_attention()

# %%
#can enable if low GPU or using cpu
#pipe.enable_attention_slicing()

# %%
prompt = ""
image = pipe(prompt).images[0]
image

# %% [markdown]
# # Test

# %%
prompt = "a portrait of a beautiful blonde woman, fine - art photography, soft portrait shot 8 k, mid length, ultrarealistic uhd faces, unsplash, kodak ultra max 800, 85 mm, intricate, casual pose, centered symmetrical composition, stunning photos, masterpiece, grainy, centered composition "
image = pipe(prompt).images[0]
image

# %% [markdown]
# # Grid Images

# %%
import torch

prompt = "Portrait of a child playing in a park, using natural lighting and candid expressions"
generator = torch.Generator("cuda").manual_seed(1024)
image = pipe(prompt, generator=generator).images[0]

image

# %%
import torch

generator = torch.Generator("cuda").manual_seed(1024)

image = pipe(prompt, num_inference_steps=15, generator=generator).images[0]

image

# %% [markdown]
# Let's first write a helper function to display a grid of images. Just run the following cell to create the `image_grid` function, or disclose the code if you are interested in how it's done.

# %%
from PIL import Image

def image_grid(imgs, rows, cols):
    assert len(imgs) == rows*cols

    w, h = imgs[0].size
    grid = Image.new('RGB', size=(cols*w, rows*h))
    grid_w, grid_h = grid.size

    for i, img in enumerate(imgs):
        grid.paste(img, box=(i%cols*w, i//cols*h))
    return grid

# %%
num_images = 3
prompt = ["Realistic painting of a quiet moment between a child and their pet, with an emphasis on expression and mood"] * num_images

images = pipe(prompt).images

grid = image_grid(images, rows=1, cols=3)
grid

# %% [markdown]
# And here's how to generate a grid of `n × m` images.

# %%
num_cols = 3
num_rows = 4

prompt = ["Realistic painting of a solitary lighthouse silhouetted against the vibrant colors of a sunset"] * num_cols

all_images = []
for i in range(num_rows):
  images = pipe(prompt).images
  all_images.extend(images)

grid = image_grid(all_images, rows=num_rows, cols=num_cols)
grid

# %%
num_cols = 3
num_rows = 4

prompt = ["Portrait of a child playing in a park, using natural lighting and candid expressions"] * num_cols

all_images = []
for i in range(num_rows):
  images = pipe(prompt).images
  all_images.extend(images)

grid = image_grid(all_images, rows=num_rows, cols=num_cols)
grid

# %%
num_cols = 3
num_rows = 4

prompt = ["Portrait of a military veteran in uniform, with strong, directional lighting"] * num_cols

all_images = []
for i in range(num_rows):
  images = pipe(prompt).images
  all_images.extend(images)

grid = image_grid(all_images, rows=num_rows, cols=num_cols)
grid

# %%
num_cols = 3
num_rows = 4

prompt = ["Portrait of a street performer in action with a bustling city as a blurred background"] * num_cols

all_images = []
for i in range(num_rows):
  images = pipe(prompt).images
  all_images.extend(images)

grid = image_grid(all_images, rows=num_rows, cols=num_cols)
grid

# %%
num_cols = 3
num_rows = 4

prompt = ["Stylized portrait of an entrepreneur against a city skyline, with dramatic lighting and a futuristic look"] * num_cols

all_images = []
for i in range(num_rows):
  images = pipe(prompt).images
  all_images.extend(images)

grid = image_grid(all_images, rows=num_rows, cols=num_cols)
grid

# %%
num_cols = 3
num_rows = 4

prompt = ["Portrait of an old fisherman at sea, using natural light to highlight weathered textures"] * num_cols

all_images = []
for i in range(num_rows):
  images = pipe(prompt).images
  all_images.extend(images)

grid = image_grid(all_images, rows=num_rows, cols=num_cols)
grid

# %%
num_cols = 3
num_rows = 4

prompt = ["Portrait of a professional dancer expressing emotion through movement, with dramatic lighting"] * num_cols

all_images = []
for i in range(num_rows):
  images = pipe(prompt).images
  all_images.extend(images)

grid = image_grid(all_images, rows=num_rows, cols=num_cols)
grid

# %%
num_cols = 3
num_rows = 4

prompt = ["Portrait of a lone hiker on a mountain peak during golden hour"] * num_cols

all_images = []
for i in range(num_rows):
  images = pipe(prompt).images
  all_images.extend(images)

grid = image_grid(all_images, rows=num_rows, cols=num_cols)
grid

# %%
num_cols = 3
num_rows = 4

prompt = ["Action portrait of an athlete during a game, using fast shutter speed and close-up shots"] * num_cols

all_images = []
for i in range(num_rows):
  images = pipe(prompt).images
  all_images.extend(images)

grid = image_grid(all_images, rows=num_rows, cols=num_cols)
grid

# %%
num_cols = 3
num_rows = 4

prompt = ["Whimsical portrait of a person in a dreamy, natural environment with soft lighting"] * num_cols

all_images = []
for i in range(num_rows):
  images = pipe(prompt).images
  all_images.extend(images)

grid = image_grid(all_images, rows=num_rows, cols=num_cols)
grid

# %%
num_cols = 3
num_rows = 4

prompt = ["Realistic painting of an autumn scene featuring a tree-lined boulevard with leaves in vibrant colors covering the ground"] * num_cols

all_images = []
for i in range(num_rows):
  images = pipe(prompt).images
  all_images.extend(images)

grid = image_grid(all_images, rows=num_rows, cols=num_cols)
grid

# %%
num_cols = 3
num_rows = 4

prompt = ["Black and white photograph of a person dressed in 1920s fashion, posing against an old brick building"] * num_cols

all_images = []
for i in range(num_rows):
  images = pipe(prompt).images
  all_images.extend(images)

grid = image_grid(all_images, rows=num_rows, cols=num_cols)
grid

# %% [markdown]
# # Single Images

# %% [markdown]
# i will try diff prompts daily and upload or update output here

# %% [markdown]
# # V1

# %%
prompt = "Joyful portrait of girlaughing in the rain, using high shutter speed to freeze raindrops"

image = pipe(prompt=prompt).images[0]
image

# %%
# 1. Portrait of a child playing in a park, using natural lighting and candid expressions
prompt = "Portrait of a child playing in a park, using natural lighting and candid expressions"
image = pipe(prompt).images[0]
image

# %%
# 2. Portrait of a military veteran in uniform, with strong, directional lighting
prompt = "Portrait of a military veteran in uniform, with strong, directional lighting"
image = pipe(prompt).images[0]
image

# %%
# 3. Portrait of a street performer in action with a bustling city as a blurred background
prompt = "Portrait of a street performer in action with a bustling city as a blurred background"
image = pipe(prompt).images[0]
image

# %%
# 4. Stylized portrait of an entrepreneur against a city skyline, with dramatic lighting and a futuristic look
prompt = "Stylized portrait of an entrepreneur against a city skyline, with dramatic lighting and a futuristic look"
image = pipe(prompt).images[0]
image

# %%
# 5. Portrait of an old fisherman at sea, using natural light to highlight weathered textures
prompt = "Portrait of an old fisherman at sea, using natural light to highlight weathered textures"
image = pipe(prompt).images[0]
image

# %%
# 6. Portrait of a professional dancer expressing emotion through movement, with dramatic lighting
prompt = "Portrait of a professional dancer expressing emotion through movement, with dramatic lighting"
image = pipe(prompt).images[0]
image

# %%
# 7. Joyful portrait of someone laughing in the rain, using high shutter speed to freeze raindrops
prompt = "Joyful portrait of someone laughing in the rain, using high shutter speed to freeze raindrops"
image = pipe(prompt).images[0]
image

# %%
# 8. Portrait of a lone hiker on a mountain peak during golden hour
prompt = "Portrait of a lone hiker on a mountain peak during golden hour"
image = pipe(prompt).images[0]
image

# %%
# 9. Action portrait of an athlete during a game, using fast shutter speed and close-up shots
prompt = "Action portrait of an athlete during a game, using fast shutter speed and close-up shots"
image = pipe(prompt).images[0]
image

# %%
# 10. Whimsical portrait of a person in a dreamy, natural environment with soft lighting
prompt = "Whimsical portrait of a person in a dreamy, natural environment with soft lighting"
image = pipe(prompt).images[0]
image

# %%
# 11. Realistic painting of an autumn scene featuring a tree-lined boulevard with leaves in vibrant colors covering the ground
prompt = "Realistic painting of an autumn scene featuring a tree-lined boulevard with leaves in vibrant colors covering the ground"
image = pipe(prompt).images[0]
image

# %%
# 12. Black and white photograph of a person dressed in 1920s fashion, posing against an old brick building
prompt = "Black and white photograph of a person dressed in 1920s fashion, posing against an old brick building"
image = pipe(prompt).images[0]
image

# %%
# 13. Realistic painting of a quiet moment between a child and their pet, with an emphasis on expression and mood
prompt = "Realistic painting of a quiet moment between a child and their pet, with an emphasis on expression and mood"
image = pipe(prompt).images[0]
image

# %%
# 14. Photograph of a busy city street at dusk, taken from a low angle, with towering buildings and vibrant neon lights
prompt = "Photograph of a busy city street at dusk, taken from a low angle, with towering buildings and vibrant neon lights"
image = pipe(prompt).images[0]
image

# %%
# 15. Realistic painting of a tranquil wilderness scene with a peaceful lake surrounded by towering pine trees at sunset
prompt = "Realistic painting of a tranquil wilderness scene with a peaceful lake surrounded by towering pine trees at sunset"
image = pipe(prompt).images[0]
image

# %%
# 16. High-resolution photograph of everyday objects against a minimalist background, focusing on detail and texture
prompt = "High-resolution photograph of everyday objects against a minimalist background, focusing on detail and texture"
image = pipe(prompt).images[0]
image

# %%
# 17. Realistic painting of a solitary lighthouse silhouetted against the vibrant colors of a sunset
prompt = "Realistic painting of a solitary lighthouse silhouetted against the vibrant colors of a sunset"
image = pipe(prompt).images[0]
image

# %%
# 18. Long-exposure photograph of a busy intersection at night, capturing the streaks of light from moving vehicles
prompt = "Long-exposure photograph of a busy intersection at night, capturing the streaks of light from moving vehicles"
image = pipe(prompt).images[0]
image

# %%
# 19. Realistic painting of a scene beneath a forest canopy, with sunlight filtering through the leaves and rich details on the forest floor
prompt = "Realistic painting of a scene beneath a forest canopy, with sunlight filtering through the leaves and rich details on the forest floor"
image = pipe(prompt).images[0]
image

# %%
# 20. Portrait photograph taken during the golden hour, focusing on the warm light and serene atmosphere
prompt = "Portrait photograph taken during the golden hour, focusing on the warm light and serene atmosphere"
image = pipe(prompt).images[0]
image

# %%
# 21. Anime scene of a protagonist fighting shadow creatures in a moonlit forest, highlighting the glowing eyes of the creatures and the determined stance of the protagonist
prompt = "Anime scene of a protagonist fighting shadow creatures in a moonlit forest, highlighting the glowing eyes of the creatures and the determined stance of the protagonist"
image = pipe(prompt).images[0]
image

# %%
# 22. Anime depiction of a futuristic Tokyo, filled with neon-lit skyscrapers, hover vehicles, and traditional elements like a Shinto shrine
prompt = "Anime depiction of a futuristic Tokyo, filled with neon-lit skyscrapers, hover vehicles, and traditional elements like a Shinto shrine"
image = pipe(prompt).images[0]
image

# %%
# 23. Anime scene featuring high school students having fun with their classmates
prompt = "Anime scene featuring high school students having fun with their classmates"
image = pipe(prompt).images[0]
image

# %%
# 24. Anime illustration of a character bonding with a majestic dragon in a secluded mountain sanctuary, focusing on the size of the dragon and the affectionate interaction
prompt = "Anime illustration of a character bonding with a majestic dragon in a secluded mountain sanctuary, focusing on the size of the dragon and the affectionate interaction"
image = pipe(prompt).images[0]
image

# %%
# 25. Anime depiction of a magic school teeming with students practicing spells and mystical creatures wandering about, rendered in a vibrant color palette and detailed artwork
prompt = "Anime depiction of a magic school teeming with students practicing spells and mystical creatures wandering about, rendered in a vibrant color palette and detailed artwork"
image = pipe(prompt).images[0]
image

# %%
# 26. Anime-style mecha warrior outfitted in heavy armor and futuristic weapons, focusing on dynamic lines and strong color contrast
prompt = "Anime-style mecha warrior outfitted in heavy armor and futuristic weapons, focusing on dynamic lines and strong color contrast"
image = pipe(prompt).images[0]
image

# %%
# 27. Anime scene of a character encountering spirits in a dense, enchanted forest, featuring a misty background, glowing plants, and whimsical creatures
prompt = "Anime scene of a character encountering spirits in a dense, enchanted forest, featuring a misty background, glowing plants, and whimsical creatures"
image = pipe(prompt).images[0]
image

# %%
# 28. Anime depiction of a cybernetic samurai in a post-apocalyptic setting, focusing on the intricacies of the armor and weaponry
prompt = "Anime depiction of a cybernetic samurai in a post-apocalyptic setting, focusing on the intricacies of the armor and weaponry"
image = pipe(prompt).images[0]
image

# %%
# 29. Anime scene of a sailor on a fantastical ship navigating the high seas and encountering sirens, focusing on the vivid colors of the sea and sky, and the expressive characters
prompt = "Anime scene of a sailor on a fantastical ship navigating the high seas and encountering sirens, focusing on the vivid colors of the sea and sky, and the expressive characters"
image = pipe(prompt).images[0]
image

# %%
# 30. Anime scene showing a group of warriors making their last stand against a monster army, highlighting the dramatic contrast of light and dark, and the warriors’ expressions of determination
prompt = "Anime scene showing a group of warriors making their last stand against a monster army, highlighting the dramatic contrast of light and dark, and the warriors’ expressions of determination"
image = pipe(prompt).images[0]
image

# %%
# 31. A man sitting on a park bench
prompt = "A man sitting on a park bench"
image = pipe(prompt).images[0]
image

# %%
# 32. A man sitting on a park bench under a tree, golden autumn leaves falling around him
prompt = "A man sitting on a park bench under a tree, golden autumn leaves falling around him"
image = pipe(prompt).images[0]
image

# %%
# 33. Impressionistic painting of an old man sitting on a park bench, feeding pigeons amidst a shower of golden autumn leaves
prompt = "Impressionistic painting of an old man sitting on a park bench, feeding pigeons amidst a shower of golden autumn leaves"
image = pipe(prompt).images[0]
image

# %%
# 34. A laughing robot in the sunset
prompt = "A laughing robot in the sunset"
image = pipe(prompt).images[0]
image

# %% [markdown]
# # V2

# %%
# 36. Sci-fi illustration of a futuristic city on a distant planet, with floating skyscrapers and advanced technology.
prompt = "Sci-fi illustration of a futuristic city on a distant planet, with floating skyscrapers and advanced technology"
image = pipe(prompt).images[0]
image

# %%
# 37. Surreal digital art of a dream-like underwater world, with floating islands and bioluminescent creatures.
prompt = "Surreal digital art of a dream-like underwater world, with floating islands and bioluminescent creatures"
image = pipe(prompt).images[0]
image

# %%
# 38. Portrait of a mythical creature, like a phoenix, in flight with vibrant flames and a dramatic sky in the background.
prompt = "Portrait of a mythical creature, like a phoenix, in flight with vibrant flames and a dramatic sky in the background"
image = pipe(prompt).images[0]
image

# %%
# 39. Steampunk-style painting of an airship navigating stormy skies with gears, cogs, and intricate machinery.
prompt = "Steampunk-style painting of an airship navigating stormy skies with gears, cogs, and intricate machinery"
image = pipe(prompt).images[0]
image

# %%
# 40. Close-up photograph of a macro world with dewdrops on spiderwebs, showcasing intricate details of nature.
prompt = "Close-up photograph of a macro world with dewdrops on spiderwebs, showcasing intricate details of nature"
image = pipe(prompt).images[0]
image

# %%
# 41. Illustration of a futuristic cyberpunk street scene with neon signs, holograms, and flying cars.
prompt = "Illustration of a futuristic cyberpunk street scene with neon signs, holograms, and flying cars"
image = pipe(prompt).images[0]
image

# %%
# 42. Portrait of a mythical forest guardian with glowing eyes and an aura of magic in an enchanted forest.
prompt = "Portrait of a mythical forest guardian with glowing eyes and an aura of magic in an enchanted forest"
image = pipe(prompt).images[0]
image

# %%
# 43. Abstract expressionist painting with bold, vibrant colors and dynamic brushstrokes, conveying energy and emotion.
prompt = "Abstract expressionist painting with bold, vibrant colors and dynamic brushstrokes, conveying energy and emotion"
image = pipe(prompt).images[0]
image

# %%
# 44. Photograph of a vintage typewriter and a cup of coffee on a cozy writing desk, evoking a sense of nostalgia.
prompt = "Photograph of a vintage typewriter and a cup of coffee on a cozy writing desk, evoking a sense of nostalgia"
image = pipe(prompt).images[0]
image

# %%
# 45. Illustration of a space explorer in a spacesuit, standing on the surface of a distant planet with alien landscapes.
prompt = "Illustration of a space explorer in a spacesuit, standing on the surface of a distant planet with alien landscapes"
image = pipe(prompt).images[0]
image

# %% [markdown]
# # V3

# %%
prompt = "Epic space battle scene with futuristic spaceships engaged in combat around a distant planet"
image = pipe(prompt).images[0]
image

# %%
# 46. Epic space battle scene with futuristic spaceships engaged in combat around a distant planet.
prompt = "Epic space battle scene with futuristic spaceships engaged in combat around a distant planet"
image = pipe(prompt).images[0]
image

# %%
# 47. Anime-style illustration of a futuristic cyberpunk cityscape with neon signs and androids.
prompt = "Anime-style illustration of a futuristic cyberpunk cityscape with neon signs and androids"
image = pipe(prompt).images[0]
image

# %%
# 48. Astronaut exploring an alien planet in a high-tech spacesuit with breathtaking views of a unique solar system.
prompt = "Astronaut exploring an alien planet in a high-tech spacesuit with breathtaking views of a unique solar system"
image = pipe(prompt).images[0]
image

# %%
# 49. Futuristic space colony on a distant moon, with advanced spacecraft and a stunning view of Earth from space.
prompt = "Futuristic space colony on a distant moon, with advanced spacecraft and a stunning view of Earth from space"
image = pipe(prompt).images[0]
image

# %%
# 50. Anime girl with cybernetic enhancements and holographic interfaces, immersed in futuristic programming and virtual reality.
prompt = "Anime girl with cybernetic enhancements and holographic interfaces, immersed in futuristic programming and virtual reality"
image = pipe(prompt).images[0]
image

# %%
# 51. High-tech future war scenario with advanced mechs and futuristic weaponry in a post-apocalyptic setting.
prompt = "High-tech future war scenario with advanced mechs and futuristic weaponry in a post-apocalyptic setting"
image = pipe(prompt).images[0]
image

# %%
# 52. Futuristic house in a lush, alien jungle, with transparent walls, advanced technology, and a harmonious connection with nature.
prompt = "Futuristic house in a lush, alien jungle, with transparent walls, advanced technology, and a harmonious connection with nature"
image = pipe(prompt).images[0]
image

# %%
# 53. Anime-style portrayal of a future girl with bioluminescent features and an ethereal aura, set in a distant galaxy.
prompt = "Anime-style portrayal of a future girl with bioluminescent features and an ethereal aura, set in a distant galaxy"
image = pipe(prompt).images[0]
image

# %%
# 54. Futuristic programming and hacking scene with a computer genius navigating a virtual world filled with digital challenges.
prompt = "Futuristic programming and hacking scene with a computer genius navigating a virtual world filled with digital challenges"
image = pipe(prompt).images[0]
image
# Out:
#   0%|          | 0/50 [00:00<?, ?it/s]

# %%
# 55. Surreal space exploration, where a lone astronaut encounters mysterious celestial beings in a cosmic dreamscape.
prompt = "Surreal space exploration, where a lone astronaut encounters mysterious celestial beings in a cosmic dreamscape"
image = pipe(prompt).images[0]
image

# %%
# 56. Anime depiction of a bustling intergalactic marketplace with alien species, exotic goods, and advanced transportation.
prompt = "Anime depiction of a bustling intergalactic marketplace with alien species, exotic goods, and advanced transportation"
image = pipe(prompt).images[0]
image

# %%
# 57. Futuristic underwater city with advanced technology and bioluminescent marine life in a post-climate-change world.
prompt = "Futuristic underwater city with advanced technology and bioluminescent marine life in a post-climate-change world"
image = pipe(prompt).images[0]
image

# %%
# 58. Anime scene of a time-traveling adventurer exploring key moments in history, preserving the space-time continuum.
prompt = "Anime scene of a time-traveling adventurer exploring key moments in history, preserving the space-time continuum"
image = pipe(prompt).images[0]
image

# %%
# 59. Futuristic space opera with a diverse crew of space explorers embarking on an epic quest across the galaxy.
prompt = "Futuristic space opera with a diverse crew of space explorers embarking on an epic quest across the galaxy"
image = pipe(prompt).images[0]
image

# %%
# 60. Anime girl as a holographic AI companion guiding a lonely traveler through a surreal, ever-changing landscape.
prompt = "Anime girl as a holographic AI companion guiding a lonely traveler through a surreal, ever-changing landscape"
image = pipe(prompt).images[0]
image

# %% [markdown]
# # v4

# %%
prompt = "Portrait of an enchanting blonde woman in fine art photography, captured in ultra-realistic UHD at 8K resolution. Shot with a soft focus, showcasing intricate details. The model's mid-length hair and stunning features are emphasized, creating a masterpiece of grainy beauty. The composition is centered and symmetrical, with the model in a casual yet captivating pose. This photograph is reminiscent of Kodak Ultra Max 800 film, shot with an 85mm lens for exceptional clarity and depth. The centered composition enhances the visual impact, making it a timeless work of art"
image = pipe(prompt).images[0]
image

# %%
prompt = "cinematic photo of 18yo girl standing on an alien planet, spaceship in background, RAW photo, high quality, 35mm photograph, film grain, bokeh, professional, 4k, highly detailed, <lora:epiCRealismHelper:0.7> <lora:more_details:0.5>"
image = pipe(prompt).images[0]
image

# %%
# 61. Futuristic space exploration with astronauts discovering a mysterious monolith on an alien moon.
prompt = "Futuristic space exploration with astronauts discovering a mysterious monolith on an alien moon"
image = pipe(prompt).images[0]
image

# %%
# 62. Anime-style depiction of a post-apocalyptic wasteland with mutated creatures and survivors in high-tech armor.
prompt = "Anime-style depiction of a post-apocalyptic wasteland with mutated creatures and survivors in high-tech armor"
image = pipe(prompt).images[0]
image

# %%
# 63. Futuristic cityscape at night with holographic billboards, flying cars, and neon-lit streets.
prompt = "Futuristic cityscape at night with holographic billboards, flying cars, and neon-lit streets"
image = pipe(prompt).images[0]
image

# %%
# 64. Anime girl as a virtual reality gamer in a cyberpunk world, battling against virtual enemies in a futuristic arena.
prompt = "Anime girl as a virtual reality gamer in a cyberpunk world, battling against virtual enemies in a futuristic arena"
image = pipe(prompt).images[0]
image

# %%
# 65. Futuristic space station orbiting a gas giant with breathtaking views of the giant's swirling storms.
prompt = "Futuristic space station orbiting a gas giant with breathtaking views of the giant's swirling storms"
image = pipe(prompt).images[0]
image

# %%
# 66. Surreal digital art of a sentient AI entity emerging from a sea of code, representing the birth of true AI consciousness.
prompt = "Surreal digital art of a sentient AI entity emerging from a sea of code, representing the birth of true AI consciousness"
image = pipe(prompt).images[0]
image

# %%
# 67. Anime depiction of a time-traveling scientist unraveling the mysteries of the universe, surrounded by complex equations and diagrams.
prompt = "Anime depiction of a time-traveling scientist unraveling the mysteries of the universe, surrounded by complex equations and diagrams"
image = pipe(prompt).images[0]
image

# %%
# 68. Futuristic fashion runway featuring avant-garde clothing and accessories inspired by space and technology.
prompt = "Futuristic fashion runway featuring avant-garde clothing and accessories inspired by space and technology"
image = pipe(prompt).images[0]
image

# %%
# 69. Anime girl as a space pirate captain, leading a crew of diverse characters on a quest for cosmic treasures.
prompt = "Anime girl as a space pirate captain, leading a crew of diverse characters on a quest for cosmic treasures"
image = pipe(prompt).images[0]
image

# %%
# 70. Futuristic transportation hub with high-speed trains, levitating pods, and commuters in futuristic attire.
prompt = "Futuristic transportation hub with high-speed trains, levitating pods, and commuters in futuristic attire"
image = pipe(prompt).images[0]
image

# %% [markdown]
# # V5

# %%
# 71. A futuristic, eco-friendly city powered by renewable energy sources and surrounded by lush green landscapes.
prompt = "A futuristic, eco-friendly city powered by renewable energy sources and surrounded by lush green landscapes"

# 72. Anime-style depiction of a talented young programmer writing code that shapes the virtual world around them.
prompt = "Anime-style depiction of a talented young programmer writing code that shapes the virtual world around them"

# 73. A visionary inventor in a steampunk laboratory, surrounded by intricate contraptions and peculiar gadgets.
prompt = "A visionary inventor in a steampunk laboratory, surrounded by intricate contraptions and peculiar gadgets"

# 74. A breathtaking view of a space station orbiting a distant planet with an otherworldly atmosphere and landscape.
prompt = "A breathtaking view of a space station orbiting a distant planet with an otherworldly atmosphere and landscape"

# 75. Surreal digital art of a cosmic entity observing the birth and death of stars in the universe's grand tapestry.
prompt = "Surreal digital art of a cosmic entity observing the birth and death of stars in the universe's grand tapestry"

# 76. Anime girl as a cyberpunk rebel leader, standing defiantly against a backdrop of neon-drenched urban chaos.
prompt = "Anime girl as a cyberpunk rebel leader, standing defiantly against a backdrop of neon-drenched urban chaos"

# 77. A mind-bending, Escher-inspired architectural marvel with impossible geometry and floating staircases.
prompt = "A mind-bending, Escher-inspired architectural marvel with impossible geometry and floating staircases"

# 78. A serene, minimalist future house with clean lines, sustainable design, and large windows overlooking nature.
prompt = "A serene, minimalist future house with clean lines, sustainable design, and large windows overlooking nature"

# 79. Anime depiction of a time-traveling explorer encountering ancient civilizations and unlocking their secrets.
prompt = "Anime depiction of a time-traveling explorer encountering ancient civilizations and unlocking their secrets"

# 80. A futuristic cityscape emerging from the clouds, perched on towering cliffs, and connected by sky bridges.
prompt = "A futuristic cityscape emerging from the clouds, perched on towering cliffs, and connected by sky bridges"

# %%
# 71. A futuristic, eco-friendly city powered by renewable energy sources and surrounded by lush green landscapes.
prompt = "A futuristic, eco-friendly city powered by renewable energy sources and surrounded by lush green landscapes"
image = pipe(prompt).images[0]
image

# %%
# 72. Anime-style depiction of a talented young programmer writing code that shapes the virtual world around them.
prompt = "Anime-style depiction of a talented young programmer writing code that shapes the virtual world around them"
image = pipe(prompt).images[0]
image

# %%
# 73. A visionary inventor in a steampunk laboratory, surrounded by intricate contraptions and peculiar gadgets.
prompt = "A visionary inventor in a steampunk laboratory, surrounded by intricate contraptions and peculiar gadgets"
image = pipe(prompt).images[0]
image

# %%
# 74. A breathtaking view of a space station orbiting a distant planet with an otherworldly atmosphere and landscape.
prompt = "A breathtaking view of a space station orbiting a distant planet with an otherworldly atmosphere and landscape"
image = pipe(prompt).images[0]
image

# %%
# 75. Surreal digital art of a cosmic entity observing the birth and death of stars in the universe's grand tapestry.
prompt = "Surreal digital art of a cosmic entity observing the birth and death of stars in the universe's grand tapestry"
image = pipe(prompt).images[0]
image

# %%
# 76. Anime girl as a cyberpunk rebel leader, standing defiantly against a backdrop of neon-drenched urban chaos.
prompt = "Anime girl as a cyberpunk rebel leader, standing defiantly against a backdrop of neon-drenched urban chaos"
image = pipe(prompt).images[0]
image

# %%
# 77. A mind-bending, Escher-inspired architectural marvel with impossible geometry and floating staircases.
prompt = "A mind-bending, Escher-inspired architectural marvel with impossible geometry and floating staircases"
image = pipe(prompt).images[0]
image

# %%
# 78. A serene, minimalist future house with clean lines, sustainable design, and large windows overlooking nature.
prompt = "A serene, minimalist future house with clean lines, sustainable design, and large windows overlooking nature"
image = pipe(prompt).images[0]
image

# %%
# 79. Anime depiction of a time-traveling explorer encountering ancient civilizations and unlocking their secrets.
prompt = "Anime depiction of a time-traveling explorer encountering ancient civilizations and unlocking their secrets"
image = pipe(prompt).images[0]
image

# %%
# 80. A futuristic cityscape emerging from the clouds, perched on towering cliffs, and connected by sky bridges.
prompt = "A futuristic cityscape emerging from the clouds, perched on towering cliffs, and connected by sky bridges"
image = pipe(prompt).images[0]
image

# %%
prompt = "Portrait of an enchanting blonde woman in ultra-realistic UHD fine art photography at 8K resolution. Shot with a soft focus, emphasizing intricate details and stunning features. Centered and symmetrical composition with a casual yet captivating pose, reminiscent of Kodak Ultra Max 800 film. Shot with an 85mm lens for clarity and depth. A timeless work of art. (Image source: Unsplash)"
image = pipe(prompt).images[0]
image

# %% [markdown]
# # V6

# %%
# 81. Realistic painting of a serene countryside landscape with rolling hills and a charming farmhouse.
prompt_81 = "Realistic painting of a serene countryside landscape with rolling hills and a charming farmhouse"
image_81 = pipe(prompt_81).images[0]
image_81

# %%
# 82. High-resolution photograph of a bustling, old-world market with vendors selling fresh produce and colorful textiles.
prompt_82 = "High-resolution photograph of a bustling, old-world market with vendors selling fresh produce and colorful textiles"
image_82 = pipe(prompt_82).images[0]
image_82

# %%
# 83. Detailed still life painting of a vase of vibrant, freshly cut flowers in soft, natural light.
prompt_83 = "Detailed still life painting of a vase of vibrant, freshly cut flowers in soft, natural light"
image_83 = pipe(prompt_83).images[0]
image_83

# %%
# 84. Close-up photograph of a weathered, well-used violin with intricate details in the wood and strings.
prompt_84 = "Close-up photograph of a weathered, well-used violin with intricate details in the wood and strings"
image_84 = pipe(prompt_84).images[0]
image_84

# %%
# 85. Realistic portrait of an elderly, wise fisherman gazing out to sea, capturing the essence of a lifetime of experiences.
prompt_85 = "Realistic portrait of an elderly, wise fisherman gazing out to sea, capturing the essence of a lifetime of experiences"
image_85 = pipe(prompt_85).images[0]
image_85

# %%
# 86. A detailed, oil painting of a cozy, candlelit library filled with antique books and plush armchairs.
prompt_86 = "A detailed, oil painting of a cozy, candlelit library filled with antique books and plush armchairs"
image_86 = pipe(prompt_86).images[0]
image_86

# %%
# 87. High-resolution photograph of a misty forest scene with sunlight filtering through the trees, creating an ethereal atmosphere.
prompt_87 = "High-resolution photograph of a misty forest scene with sunlight filtering through the trees, creating an ethereal atmosphere"
image_87 = pipe(prompt_87).images[0]
image_87

# %%
# 88. Realistic still life painting of a table set for an elegant dinner, complete with fine china, crystal glassware, and polished silverware.
prompt_88 = "Realistic still life painting of a table set for an elegant dinner, complete with fine china, crystal glassware, and polished silverware"
image_88 = pipe(prompt_88).images[0]
image_88

# %%
# 89. Close-up photograph of a skilled blacksmith at work, showcasing the forging process and the red-hot metal.
prompt_89 = "Close-up photograph of a skilled blacksmith at work, showcasing the forging process and the red-hot metal"
image_89 = pipe(prompt_89).images[0]
image_89

# %%
# 90. Realistic portrait of an accomplished pianist lost in the music, fingers gracefully dancing on the keys.
prompt_90 = "Realistic portrait of an accomplished pianist lost in the music, fingers gracefully dancing on the keys"
image_90 = pipe(prompt_90).images[0]
image_90

# %% [markdown]
# # V7

# %%
# 1. Captivating fine art photography of a graceful ballerina in a picturesque garden, shot in ultra-realistic UHD at 8K resolution. Soft focus highlights her intricate movements and the delicate balance of nature. The composition is centered, with the dancer's pose evoking timeless beauty and elegance. This photograph captures the essence of a serene moment in a world of motion.
prompt_1 = "Captivating fine art photography of a graceful ballerina in a picturesque garden, shot in ultra-realistic UHD at 8K resolution. Soft focus highlights her intricate movements and the delicate balance of nature. The composition is centered, with the dancer's pose evoking timeless beauty and elegance. This photograph captures the essence of a serene moment in a world of motion."
image_1 = pipe(prompt_1).images[0]
image_1

# %%
# 2. A charming countryside scene with a couple strolling hand in hand through a golden wheat field at sunset. Shot in ultra-realistic UHD at 8K resolution, the soft focus accentuates the warmth and intimacy of the moment. The composition is centered and symmetrical, creating a timeless snapshot of love in the great outdoors.
prompt_2 = "A charming countryside scene with a couple strolling hand in hand through a golden wheat field at sunset. Shot in ultra-realistic UHD at 8K resolution, the soft focus accentuates the warmth and intimacy of the moment. The composition is centered and symmetrical, creating a timeless snapshot of love in the great outdoors."
image_2 = pipe(prompt_2).images[0]
image_2

# %%
# 3. An enchanting forest nymph surrounded by the soft glow of bioluminescent mushrooms. Shot in ultra-realistic UHD at 8K resolution, the soft focus captures the ethereal quality of this mythical creature. The composition is centered and symmetrical, making it a captivating glimpse into a mystical world.
prompt_3 = "An enchanting forest nymph surrounded by the soft glow of bioluminescent mushrooms. Shot in ultra-realistic UHD at 8K resolution, the soft focus captures the ethereal quality of this mythical creature. The composition is centered and symmetrical, making it a captivating glimpse into a mystical world."
image_3 = pipe(prompt_3).images[0]
image_3

# %%
# 4. A breathtaking view of a majestic mountain range at sunrise, with the first light casting a warm, golden hue on the peaks. Shot in ultra-realistic UHD at 8K resolution, the soft focus enhances the natural beauty of the landscape. The composition is centered, showcasing the grandeur of nature in all its glory.
prompt_4 = "A breathtaking view of a majestic mountain range at sunrise, with the first light casting a warm, golden hue on the peaks. Shot in ultra-realistic UHD at 8K resolution, the soft focus enhances the natural beauty of the landscape. The composition is centered, showcasing the grandeur of nature in all its glory."
image_4 = pipe(prompt_4).images[0]
image_4

# %%
# 5. A stunning underwater photograph of a school of colorful tropical fish swimming through a vibrant coral reef. Shot in ultra-realistic UHD at 8K resolution, the soft focus highlights the intricate details of the marine life. The composition is centered, offering a mesmerizing window into the world beneath the waves.
prompt_5 = "A stunning underwater photograph of a school of colorful tropical fish swimming through a vibrant coral reef. Shot in ultra-realistic UHD at 8K resolution, the soft focus highlights the intricate details of the marine life. The composition is centered, offering a mesmerizing window into the world beneath the waves."
image_5 = pipe(prompt_5).images[0]
image_5

# %%
# 6. A romantic scene of a couple dancing in a moonlit garden, with the soft glow of fairy lights creating a magical atmosphere. Shot in ultra-realistic UHD at 8K resolution, the soft focus captures the essence of love and enchantment. The composition is centered and symmetrical, evoking a timeless fairy tale.
prompt_6 = "A romantic scene of a couple dancing in a moonlit garden, with the soft glow of fairy lights creating a magical atmosphere. Shot in ultra-realistic UHD at 8K resolution, the soft focus captures the essence of love and enchantment. The composition is centered and symmetrical, evoking a timeless fairy tale."
image_6 = pipe(prompt_6).images[0]
image_6

# %%
# 7. An atmospheric portrait of an elegant lady in a vintage ball gown, standing on the grand staircase of an opulent mansion. Shot in ultra-realistic UHD at 8K resolution, the soft focus enhances the glamour and sophistication of the scene. The composition is centered, reminiscent of classic Hollywood elegance.
prompt_7 = "An atmospheric portrait of an elegant lady in a vintage ball gown, standing on the grand staircase of an opulent mansion. Shot in ultra-realistic UHD at 8K resolution, the soft focus enhances the glamour and sophistication of the scene. The composition is centered, reminiscent of classic Hollywood elegance."
image_7 = pipe(prompt_7).images[0]
image_7

# %%
# 8. A tranquil seascape with a sailboat at anchor on a calm, moonlit night. Shot in ultra-realistic UHD at 8K resolution, the soft focus adds a dreamlike quality to the serene scene. The composition is centered, capturing the peace and beauty of a quiet night on the water.
prompt_8 = "A tranquil seascape with a sailboat at anchor on a calm, moonlit night. Shot in ultra-realistic UHD at 8K resolution, the soft focus adds a dreamlike quality to the serene scene. The composition is centered, capturing the peace and beauty of a quiet night on the water."
image_8 = pipe(prompt_8).images[0]
image_8

# %%
# 9. A majestic winter landscape with a lone wolf standing in a snow-covered forest. Shot in ultra-realistic UHD at 8K resolution, the soft focus accentuates the wild and untamed beauty of the creature and its surroundings. The composition is centered, conveying the raw power of nature.
prompt_9 = "A majestic winter landscape with a lone wolf standing in a snow-covered forest. Shot in ultra-realistic UHD at 8K resolution, the soft focus accentuates the wild and untamed beauty of the creature and its surroundings. The composition is centered, conveying the raw power of nature."
image_9 = pipe(prompt_9).images[0]
image_9

# %%
# 10. A timeless portrait of a multi-generational family gathered around a bonfire, sharing stories under a starry night sky. Shot in ultra-realistic UHD at 8K resolution, the soft focus emphasizes the warmth and togetherness of the moment. The composition is centered and symmetrical, portraying the bonds of love and family.
prompt_10 = "A timeless portrait of a multi-generational family gathered around a bonfire, sharing stories under a starry night sky. Shot in ultra-realistic UHD at 8K resolution, the soft focus emphasizes the warmth and togetherness of the moment. The composition is centered and symmetrical, portraying the bonds of love and family."
image_10 = pipe(prompt_10).images[0]
image_10

# %% [markdown]
# # V8

# %%
# Cyberpunk Prompts
# 1. A neon-soaked cyberpunk cityscape with towering skyscrapers and futuristic vehicles speeding through the rain-soaked streets.
prompt_cyberpunk_1 = "A neon-soaked cyberpunk cityscape with towering skyscrapers and futuristic vehicles speeding through the rain-soaked streets"
image_cyberpunk_1 = pipe(prompt_cyberpunk_1).images[0]
image_cyberpunk_1

# %%
# 2. A hacker's lair in a dystopian future, with holographic screens, cascading lines of code, and a mysterious figure in the shadows.
prompt_cyberpunk_2 = "A hacker's lair in a dystopian future, with holographic screens, cascading lines of code, and a mysterious figure in the shadows"
image_cyberpunk_2 = pipe(prompt_cyberpunk_2).images[0]
image_cyberpunk_2

# %%
# 3. A futuristic cybernetic assassin preparing for a mission, with augmented limbs and high-tech weaponry.
prompt_cyberpunk_3 = "A futuristic cybernetic assassin preparing for a mission, with augmented limbs and high-tech weaponry"
image_cyberpunk_3 = pipe(prompt_cyberpunk_3).images[0]
image_cyberpunk_3

# %%
# 4. A gritty, rain-drenched alleyway in a cyberpunk metropolis, with flickering neon signs and characters in trench coats.
prompt_cyberpunk_4 = "A gritty, rain-drenched alleyway in a cyberpunk metropolis, with flickering neon signs and characters in trench coats"
image_cyberpunk_4 = pipe(prompt_cyberpunk_4).images[0]
image_cyberpunk_4

# %%
# 5. A high-speed chase through a futuristic cyberpunk highway, with hovering vehicles and neon-lit tunnels.
prompt_cyberpunk_5 = "A high-speed chase through a futuristic cyberpunk highway, with hovering vehicles and neon-lit tunnels"
image_cyberpunk_5 = pipe(prompt_cyberpunk_5).images[0]
image_cyberpunk_5

# %%
# Real-World Prompts
# 6. A serene sunset over a tranquil lakeside cabin, with reflections on the calm water and a cozy, inviting atmosphere.
prompt_realworld_6 = "A serene sunset over a tranquil lakeside cabin, with reflections on the calm water and a cozy, inviting atmosphere"
image_realworld_6 = pipe(prompt_realworld_6).images[0]
image_realworld_6

# %%
# 7. A bustling street market in Marrakech, with vibrant colors, exotic spices, and the rich scents of Moroccan cuisine.
prompt_realworld_7 = "A bustling street market in Marrakech, with vibrant colors, exotic spices, and the rich scents of Moroccan cuisine"
image_realworld_7 = pipe(prompt_realworld_7).images[0]
image_realworld_7

# %%
# 8. A candid street photography shot of a street musician playing a soulful tune on a saxophone in the heart of New Orleans.
prompt_realworld_8 = "A candid street photography shot of a street musician playing a soulful tune on a saxophone in the heart of New Orleans"
image_realworld_8 = pipe(prompt_realworld_8).images[0]
image_realworld_8

# %%
# 9. A panoramic view of a pristine, snow-covered mountain range with a clear blue sky and the sense of crisp, clean air.
prompt_realworld_9 = "A panoramic view of a pristine, snow-covered mountain range with a clear blue sky and the sense of crisp, clean air"
image_realworld_9 = pipe(prompt_realworld_9).images[0]
image_realworld_9

# %%
# 10. A cozy reading nook with a sunlit window, comfortable armchair, and a shelf full of well-loved books, creating the perfect atmosphere for getting lost in a story.
prompt_realworld_10 = "A cozy reading nook with a sunlit window, comfortable armchair, and a shelf full of well-loved books, creating the perfect atmosphere for getting lost in a story"
image_realworld_10 = pipe(prompt_realworld_10).images[0]
image_realworld_10
